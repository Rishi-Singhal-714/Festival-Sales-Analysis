# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

Data = pd.read_csv('Diwali Sales Data.csv',encoding='unicode_escape')
#UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 267: invalid start byte
#to avoid this error use (encoding='unicode_escape')-> This will bypass invalid bytes, making it easier to load files with mixed or unknown encodings.

# %%
Data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
Data.shape
# Out:
# (11251, 15)

# %%
Data.head(30)
# Out:
#     User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903    Sanskriti  P00125942      F     26-35   28               0
# 1   1000732       Kartik  P00110942      F     26-35   35               1
# 2   1001990        Bindu  P00118542      F     26-35   35               1
# 3   1001425       Sudevi  P00237842      M      0-17   16               0
# 4   1000588         Joni  P00057942      M     26-35   28               1
# 5   1000588         Joni  P00057942      M     26-35   28               1
# 6   1001132         Balk  P00018042      F     18-25   25               1
# 7   1002092     Shivangi  P00273442      F       55+   61               0
# 8   1003224       Kushal  P00205642      M     26-35   35               0
# 9   1003650        Ginny  P00031142      F     26-35   26               1
# 10  1003829     Harshita  P00200842      M     26-35   34               0
# 11  1000214     Kargatis  P00119142      F     18-25   20               0
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#Missing Data:
#Columns Status and unnamed1 have 0 non-null values, meaning they contain no useful information. Consider dropping these columns.
#The Amount column has 12 missing values. You could handle these by either imputing with the mean/median or dropping those rows, depending on your analysis goals.

# %%
Data.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#Amount:12 Null Values we will Drop them as well

# %%
Data.dropna(inplace=True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
# 11251 -> 11239

# %%
Data.head(30)
# Out:
#     User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903    Sanskriti  P00125942      F     26-35   28               0
# 1   1000732       Kartik  P00110942      F     26-35   35               1
# 2   1001990        Bindu  P00118542      F     26-35   35               1
# 3   1001425       Sudevi  P00237842      M      0-17   16               0
# 4   1000588         Joni  P00057942      M     26-35   28               1
# 5   1000588         Joni  P00057942      M     26-35   28               1
# 6   1001132         Balk  P00018042      F     18-25   25               1
# 8   1003224       Kushal  P00205642      M     26-35   35               0
# 9   1003650        Ginny  P00031142      F     26-35   26               1
# 10  1003829     Harshita  P00200842      M     26-35   34               0
# 11  1000214     Kargatis  P00119142      F     18-25   20               0
# 12  1004035       Elijah  P00080342      F     18-25   20               1
# ...

# %%
Data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
Data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610858
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
A = sns.countplot(x = 'Gender',data=Data)
A.bar_label(A.containers[0])
# Out:
# [Text(0, 0, '7832'), Text(0, 0, '3407')]

# %%
#The dataset shows a significantly higher number of female customers compared to male customers. This indicates a potential market skew towards females, which can be crucial for targeted marketing strategies.

# %%
Sales_Gender_Data = Data.groupby(['Gender'],as_index = False)['Amount'].sum()

# %%
Sales_Gender_Data
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
sns.barplot(x='Gender',y='Amount',data=Sales_Gender_Data)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
Sales_Age_Group_Data=sns.countplot(x='Age Group',data= Data,hue='Gender')
for bars in Sales_Age_Group_Data.containers:
    Sales_Age_Group_Data.bar_label(bars)

# %%
Sales_Age_Group_Data2 = Data.groupby(['Age Group','Gender'],as_index = False)['Amount'].sum()

# %%
#Females consistently outspend males across all age groups.
#Spending appears to peak in the 26-35 age group.

# %%
Sales_State_Data=Data.groupby(['State'],as_index=False)['Orders'].sum()

# %%
sns.set(rc = {'figure.figsize':(30,10)})
sns.barplot(x='State',y ='Orders',data = Sales_State_Data)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
Sales_State_Data2 =Data.groupby(['State'],as_index=False)['Orders'].sum()

# %%
Sales_State_Data2
# Out:
#                State  Orders
# 0     Andhra Pradesh    2051
# 1              Bihar    1062
# 2              Delhi    2740
# 3            Gujarat    1066
# 4            Haryana    1109
# 5   Himachal Pradesh    1568
# 6          Jharkhand     953
# 7          Karnataka    3240
# 8             Kerala    1137
# 9     Madhya Pradesh    2252
# 10       Maharashtra    3810
# 11            Punjab     495
# 12         Rajasthan     555
# 13         Telangana     312
# 14     Uttar Pradesh    4807
# 15       Uttarakhand     824

# %%
Sales_State_Data3 =Data.groupby(['State','Gender'],as_index=False)['Orders'].sum()

# %%
Sales_State_Data3
# Out:
#                State Gender  Orders
# 0     Andhra Pradesh      F    1391
# 1     Andhra Pradesh      M     660
# 2              Bihar      F     749
# 3              Bihar      M     313
# 4              Delhi      F    1868
# 5              Delhi      M     872
# 6            Gujarat      F     758
# 7            Gujarat      M     308
# 8            Haryana      F     806
# 9            Haryana      M     303
# 10  Himachal Pradesh      F    1079
# 11  Himachal Pradesh      M     489
# 12         Jharkhand      F     667
# 13         Jharkhand      M     286
# 14         Karnataka      F    2265
# 15         Karnataka      M     975
# 16            Kerala      F     798
# 17            Kerala      M     339
# 18    Madhya Pradesh      F    1527
# 19    Madhya Pradesh      M     725
# 20       Maharashtra      F    2813
# 21       Maharashtra      M     997
# 22            Punjab      F     320
# 23            Punjab      M     175
# 24         Rajasthan      F     359
# ...

# %%
Sales_State_Data4 =Data.groupby(['State','Gender'],as_index=False)['Amount'].sum()

# %%
Sales_State_Data4
# Out:
#                State Gender       Amount
# 0     Andhra Pradesh      F   5511219.99
# 1     Andhra Pradesh      M   2525927.00
# 2              Bihar      F   2819281.00
# 3              Bihar      M   1203476.00
# 4              Delhi      F   8264499.45
# 5              Delhi      M   3339320.00
# 6            Gujarat      F   2832262.00
# 7            Gujarat      M   1113820.00
# 8            Haryana      F   3198296.00
# 9            Haryana      M   1021879.00
# 10  Himachal Pradesh      F   3163299.00
# 11  Himachal Pradesh      M   1800069.00
# 12         Jharkhand      F   1954275.00
# 13         Jharkhand      M   1072181.00
# 14         Karnataka      F   9933966.00
# 15         Karnataka      M   3589574.00
# 16            Kerala      F   2644087.99
# 17            Kerala      M   1250404.00
# 18    Madhya Pradesh      F   5301046.00
# 19    Madhya Pradesh      M   2800096.00
# 20       Maharashtra      F  10560976.00
# 21       Maharashtra      M   3866567.00
# ...

# %%
#•	Uttar Pradesh has the highest sales amount for females at 13,662,105.00, followed by Maharashtra at 10,560,976.00.

# %%
C=sns.countplot(x='Marital_Status',data=Data)
for bars in C.containers:
    C.bar_label(bars)

# %%
Sale_Marital_Data= Data.groupby(['Marital_Status','Gender'],as_index = False)['Amount'].sum()
sns.barplot(x = 'Marital_Status',y= 'Amount',hue = 'Gender',data = Sale_Marital_Data)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
Sale_Marital_Data
# Out:
#    Marital_Status Gender       Amount
# 0               0      F  43786648.44
# 1               0      M  18338738.00
# 2               1      F  30549207.99
# 3               1      M  13574538.00

# %%
Sale_Marital_Data2= Data.groupby(['Marital_Status','Gender','State'],as_index = False)['Amount'].sum()

# %%
Sale_Marital_Data2
# Out:
#     Marital_Status Gender           State      Amount
# 0                0      F  Andhra Pradesh  3270401.00
# 1                0      F           Bihar  1499035.00
# 2                0      F           Delhi  4878275.45
# 3                0      F         Gujarat  1836541.00
# 4                0      F         Haryana  1848410.00
# ..             ...    ...             ...         ...
# 59               1      M          Punjab   290448.00
# 60               1      M       Rajasthan   289393.00
# 61               1      M       Telangana   159086.00
# 62               1      M   Uttar Pradesh  2493219.00
# 63               1      M     Uttarakhand   340086.00
#
# [64 rows x 4 columns]

# %%
#The total amount spent by females significantly exceeds that of males in both single and married categories, indicating higher purchasing power or propensity among females
#Uttar Pradesh stands out as the state with the highest spending across both marital statuses for both genders.
#Maharashtra and Karnataka also show significant spending by both genders, indicating strong market potential in these regions.

# %%
sns.set(rc={'figure.figsize':(20,5)})
D = sns.countplot(data = Data, x = 'Occupation')
for bars in D.containers:
    D.bar_label(bars)

# %%
Sales_Occupation_Data2 = Data.groupby(['Occupation','Marital_Status','State'],as_index=False)['Amount'].sum()

# %%
Sales_Occupation_Data2
# Out:
#       Occupation  Marital_Status           State    Amount
# 0    Agriculture               0  Andhra Pradesh   97100.0
# 1    Agriculture               0           Bihar   69588.0
# 2    Agriculture               0           Delhi  165492.0
# 3    Agriculture               0         Gujarat   57819.0
# 4    Agriculture               0         Haryana   51133.0
# ..           ...             ...             ...       ...
# 473      Textile               1          Punjab   15935.0
# 474      Textile               1       Rajasthan   21501.0
# 475      Textile               1       Telangana   11764.0
# 476      Textile               1   Uttar Pradesh  194328.0
# 477      Textile               1     Uttarakhand   36916.0
#
# [478 rows x 4 columns]

# %%
Sales_Occupation_Data2.to_csv('data2.csv', index=False)

# %%
Sales_Occupation_Data2 = Data.groupby(['Occupation'],as_index=False)['Amount'].sum()

Sales_Occupation_Data2
# Out:
#          Occupation       Amount
# 0       Agriculture   2593087.00
# 1        Automobile   5368596.00
# 2          Aviation  12602298.00
# 3           Banking  10770610.95
# 4          Chemical   5297436.00
# 5      Construction   3597511.00
# 6   Food Processing   4070670.00
# 7              Govt   8517212.00
# 8        Healthcare  13034587.49
# 9       Hospitality   6376405.00
# 10        IT Sector  14755079.00
# 11           Lawyer   4981665.00
# 12            Media   6295832.99
# 13           Retail   4783170.00
# 14          Textile   3204972.00

# %%
#IT Sector leads with 14,755,079.00, indicating a strong purchasing power among professionals in this field.
#The Healthcare occupation follows closely with 13,034,587.49, suggesting significant spending by healthcare professionals.
#Aviation also contributes significantly with 12,602,298.00, reflecting robust financial capacity.

# %%
sns.set(rc = {'figure.figsize':(20,6)})
Sales_Product_Category_Data = sns.countplot(x = 'Product_Category', data = Data)
for bars in Sales_Product_Category_Data.containers:
    Sales_Product_Category_Data.bar_label(bars)

# %%
Sales_Occupation_Data2 = Data.groupby(['Product_Category'],as_index=False)['Orders'].sum()

# %%
Sales_Occupation_Data2
# Out:
#          Product_Category  Orders
# 0                    Auto     239
# 1                  Beauty    1086
# 2                   Books     245
# 3      Clothing & Apparel    6634
# 4                   Decor     235
# 5   Electronics & Gadgets    5226
# 6                    Food    6110
# 7        Footwear & Shoes    2646
# 8               Furniture     889
# 9            Games & Toys     940
# 10     Hand & Power Tools      80
# 11        Household items    1331
# 12                 Office     261
# 13               Pet Care     536
# 14        Sports Products     870
# 15             Stationery     281
# 16             Tupperware     166
# 17             Veterinary     206

# %%
Sales_Occupation_Data3 = Data.groupby(['Product_Category'],as_index=False)['Amount'].sum()
Sales_Occupation_Data3
# Out:
#          Product_Category       Amount
# 0                    Auto   1958609.99
# 1                  Beauty   1959484.00
# 2                   Books   1061478.00
# 3      Clothing & Apparel  16495019.00
# 4                   Decor    730360.00
# 5   Electronics & Gadgets  15643846.00
# 6                    Food  33933883.50
# 7        Footwear & Shoes  15575209.45
# 8               Furniture   5440051.99
# 9            Games & Toys   4331694.00
# 10     Hand & Power Tools    405618.00
# 11        Household items   1569337.00
# 12                 Office     81936.00
# 13               Pet Care    482277.00
# 14        Sports Products   3635933.00
# 15             Stationery   1676051.50
# 16             Tupperware   1155642.00
# 17             Veterinary    112702.00

# %%
#The highest revenues in Food, Clothing & Apparel, and Electronics & Gadgets, businesses can focus marketing efforts and promotions in these categories to maximize sales potential.

# %%
#top 10 most sold products(same as above groupby)
Sales_Top10_=Data.groupby('Product_Category')['Orders'].sum().nlargest(10).sort_values(ascending = False).plot(kind='bar')

# %%
#Insights:
#Target Demographic:
#Unmarried Women aged 26-35 years.

#Geographical Focus:
#Primarily from Uttar Pradesh, Maharashtra, and Karnataka.

#Occupational Background:
#Working in sectors such as IT, Healthcare, and Aviation.

#Product Preferences:
#High likelihood of purchasing from the following categories:
#Food
#Clothing
#Electronics

#Implications:
#Marketing Strategies:
#Tailor marketing campaigns targeting unmarried women in the specified age group within these states, highlighting products in the Food, Clothing, and Electronics categories.

#Product Development:
#Consider developing or promoting products that align with the lifestyle and preferences of this demographic, potentially incorporating health, convenience, and fashion elements.

#Promotional Offers:
#Special promotions or bundles that combine food, clothing, and electronics could appeal to this group, encouraging higher engagement and sales.

# %%
Sales_Top10_Data=Data.groupby(['Cust_name'],as_index=False)['Amount'].sum().sort_values(ascending = False,by = 'Amount').head(10)

# %%
Sales_Top10_Data = Data.groupby(['Cust_name','Gender'],as_index=False)['Amount'].sum().sort_values(ascending = True,by = 'Amount').head(10)
sns.barplot(data = Sales_Top10_Data, x = 'Cust_name', y = 'Amount')
# Out:
# <Axes: xlabel='Cust_name', ylabel='Amount'>

# %%
Sales_Top10_Data
# Out:
#         Cust_name Gender  Amount
# 2132      Waldorf      M   761.0
# 1824        Shaun      M   762.0
# 378        Carter      M   774.0
# 987       Jayanti      F   952.0
# 1150    Latchford      M  1488.0
# 1214  Madan Mohan      M  1545.0
# 285         Blume      M  1590.0
# 1455         Nona      M  1599.0
# 86         Anchal      M  1681.0
# 2049          Tom      M  1835.0
